# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

f = open("subtitle.txt", "r")
#initialising word count and array to store all the words once cleaned
wordcount = 0
wordArr = []
summArr = []
stop_words = set(stopwords.words('english'))

#iterate through line by line to remove \n
for line in f:
    if line != "\n":
        line = line.strip("\n")

        #splitting each line by spaces
        words = line.split(" ")

        #placing everything in an array
        for word in words:
            word = word.strip(".")
            word = word.strip("?")
            word = word.strip(",")
            word = word.lower()
            
            if not word in stop_words:
                wordArr.append(word)
                #wordcount
                wordcount += 1

print(summArr)
print(wordArr)
f.close()

#counting number of each word 
counter = {}
for i in wordArr:
    if i in counter:
        counter[i] += 1
    else:
        counter[i] = 1

#print(counter)
wordVals = []
wordKeys = []
for x in counter.values():
    wordVals.append(x)

for y in counter.keys():
    wordKeys.append(y)
#print(wordVals)
#print(wordKeys)
highestVal = wordVals[1]
highestIndex = 0
highestKey = ""

for j in wordVals:
    if highestVal < wordVals[j]:
        highestVal = wordVals[j]
        highestIndex = j
        highestKey = wordKeys[j]
print(highestVal)
print(highestIndex)
print(highestKey)
# Out:
# []
# ...

# %%
def summariseFn(txtFile, storeArr):
    for line in txtFile:
        if line != "\n":
            line = line.strip("\n")
            sentences = line.split(".")
            sentences = sentences.lower
            storeArr.append(sentences)
    print(storeArr)

# %% [markdown]
# <H1>ESSENTIAL CODE HERE</H1>

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

f = open("subtitle.txt", "r")
#initialising word count and array to store all the words once cleaned
wordcount = 0
wordArr = []
stop_words = set(stopwords.words('english'))

#iterate through line by line to remove \n
for line in f:
    if line != "\n":
        line = line.strip("\n")

        #splitting each line by spaces
        words = line.split(" ")

        #placing everything in an array
        for word in words:
            word = word.strip(".")
            word = word.strip("?")
            word = word.strip(",")
            word = word.lower()
            
            if not word in stop_words:
                wordArr.append(word)
                #wordcount
                wordcount += 1
#print(wordArr)
f.close()

f = open("subtitle.txt", "r")
#initialising summ array to store
wrdArr = []
summArr = []

#iterate through line by line to remove \n
for line in f:
    if line != "\n":
        line = line.strip("\n")

        #splitting each line by spaces
        wrds = line.split(" ")

        #placing everything in an array
        for wrd in wrds:
            wrd = wrd.lower()
            if not wrd in stop_words:
                wrdArr.append(wrd)

i=0
newChunk = True
for unit in wrdArr:
    if newChunk == True:
        summArr.append(unit)
        newChunk = False
    elif "." in unit:
        summArr[i] = summArr[i] + " " + unit
        if unit == wrdArr[-1]:
            break
        else:
            i = i+1
            newChunk = True
    else:
        summArr[i] = summArr[i] + " " + unit
    
#print(wrdArr)
print(summArr)
# Out:
# ["we've chance explore development environments figure tools we'll working with.", 'start think python constructing code python.', "let's look things python.", 'one conventions around python use indentation show belonging, show something happening part something else.', "say python strict indentation, means code indented underneath particular set features code we're using belongs code sense operations performed result that.", "we've got two examples here.", "we've got function something could relevant functions career, could counting, could performing input, output type function, case, we've actually got print statement, doing, that's indented.", "case, statement, conditional statement uses indentation describe something that's going happen condition met true, something.", "quickly easily see indentations what's actually happening result code.", 'python, also see something called operators, essentially functions perform calculations, things like that.', "classic ones addition, subtra
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

f = open("subtitle.txt", "r")
#initialising word count and array to store all the words once cleaned
wordcount = 0
wordArr = []
stop_words = set(stopwords.words('english'))

#iterate through line by line to remove \n
for line in f:
    if line != "\n":
        line = line.strip("\n")

        #splitting each line by spaces
        words = line.split(" ")

        #placing everything in an array
        for word in words:
            word = word.strip(".")
            word = word.strip("?")
            word = word.strip(",")
            word = word.lower()
            
            if not word in stop_words:
                wordArr.append(word)
                #wordcount
                wordcount += 1
#print(wordArr)
f.close()

f = open("subtitle.txt", "r")
summArr = []
for line in f:
    if line != "\n":
        line = line.strip("\n")
        if "." in line:
            sentences = line.split(".")
            
        #sentences = sentences.lower()
        summArr.append(sentences)
for sentence in sentences:
    
                
print(summArr)
f.close()

# %%
import numpy as np
import networkx as nx
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance

 
def read_article(file_name):
    file = open(file_name, "r")
    filedata = file.readlines()
    article = filedata[0].split(". ")
    sentences = []

    for sentence in article:
        print(sentence)
        sentences.append(sentence.replace("[^a-zA-Z]", " ").split(" "))
    sentences.pop() 
    
    return sentences

def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
 
    all_words = list(set(sent1 + sent2))
 
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)
 
def build_similarity_matrix(sentences, stop_words):
    # Create an empty similarity matrix
    similarity_matrix = np.zeros((len(sentences), len(sentences)))
 
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
            if idx1 == idx2: #ignore if both are same sentences
                continue 
            similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1], sentences[idx2], stop_words)

    return similarity_matrix


def generate_summary(file_name, top_n=5):
    stop_words = stopwords.words('english')
    summarize_text = []

    # Step 1 - Read text anc split it
    sentences =  read_article(file_name)

    # Step 2 - Generate Similary Martix across sentences
    sentence_similarity_martix = build_similarity_matrix(sentences, stop_words)

    # Step 3 - Rank sentences in similarity martix
    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_martix)
    scores = nx.pagerank(sentence_similarity_graph)

    # Step 4 - Sort the rank and pick top sentences
    ranked_sentence = sorted(((scores[i],s) for i,s in enumerate(sentences)), reverse=True)    
    print("Indexes of top ranked_sentence order are ", ranked_sentence)    

    for i in range(top_n):
      summarize_text.append(" ".join(ranked_sentence[i][1]))

    # Step 5 - Offcourse, output the summarize texr
    print("Summarize Text: \n", ". ".join(summarize_text))

# let's begin
generate_summary("editSub.txt", 5)

# %%
f = open("subtitle.txt", "r")
ff = open("editSub.txt", "w")
#initialising word count and array to store all the words once cleaned
wordcount = 0
wordArr = []

#iterate through line by line to remove \n
for line in f:
    if line != "\n":
        line = line.strip("\n")
        ff.write(line)
        ff.write(" ")


#print(wordArr)
f.close()
